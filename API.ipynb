# %% [markdown]
# <a href="https://colab.research.google.com/github/HEMAMBIKA-SAIDU/base/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '5151a1c1-65f5-4d74-a2b0-e6a6f03b942c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:17:09.915Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 9008, 'name': 'u3x5ho386fb', 'symbol': '0mw6pedahf0s', 'slug': 'krmw3almsb', 'cmc_rank': 1222, 'num_market_pairs': 8784, 'circulating_supply': 7616, 'total_supply': 817, 'max_supply': 186, 'infinite_supply': None, 'last_updated': '2024-02-20T06:17:09.914Z', 'date_added': '2024-02-20T06:17:09.914Z', 'tags': ['k5yu3b4o1mf', '3ftbp5gv00p', 'e289ymq6cu', '83zx9u6w2cj', 'aex4fzlkofb', '0mx6zylfsdr', 'y7scablq9ag', 'djfh7ientav', 'bnvn3m6r62', 'iy0w2pxsj9'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9596109548030018, 'volume_24h': 9048, 'volume_change_24h': 0.6344072447979356, 'percent_change_1h': 0.7533780956074276, 'percent_change_24h': 0.5342315335123318, 'percent_change_7d': 0.7403457116332184, 'market_cap': 0.3755672375575052, 'market_cap_dominance'
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm = pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  7789  yu89qk864ch  58k4ft3ycei   pkkii4xdmy      9481              9435
# 1   909  1qsjc4vtkkb  hdb63xm1kzk  41zmhb6sdee      7906              1000
# 2  5706  1bh8rvxfdc4  ewj391cnnit  h5um5eqoc6q      3888              9636
# 3  9225  f4m3gfdi6kt  t9pgi2ro7uj  dvqsnreuuj8      6187              9300
# 4  9912  tlqvtzu8ila  htcwcsizgc5  3h7tkosv4ct      6968              3575
# 5   648  qah9frjpeag  hrprgfe04kp   jlxoqycvti      5842              3554
# 6  6549  3240l2k4zpl  i84yc2wz7vr   wr20cugsfk      9481              6441
# 7  6751  ckmgx4tkqdg  qca8e8t6h6n  ek886mpzl9i      2427              6858
# 8  1080  u01dn88ndip  6xg0mc6609l   kxuu0s50tk      2254              7148
# 9  1751  3ve0srsvqvr  iuwlii4wshh   skjlbislz5      4323               899
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                8459          3682        3648            None  ...
# ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '5151a1c1-65f5-4d74-a2b0-e6a6f03b942c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:01:28.422Z', 'error_code': 0, 'error_message': None, 'elapsed': 1577, 'credit_count': 3, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', '
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm = pd.json_normalize(data['data'])

# %%
norm
# Out:
#         id              name  symbol                  slug  num_market_pairs  \
# 0        1           Bitcoin     BTC               bitcoin             10821
# 1     1027          Ethereum     ETH              ethereum              8428
# 2      825       Tether USDt    USDT                tether             74897
# 3     1839               BNB     BNB                   bnb              2070
# 4     5426            Solana     SOL                solana               626
# ..     ...               ...     ...                   ...               ...
# 495   9176  RocketX exchange     RVF  rocket-vault-rocketx                64
# 496  19055   Solidus Ai Tech  AITECH       solidus-ai-tech                45
# 497   3884        Function X      FX            function-x                30
# 498   3661  Stronghold Token     SHX      stronghold-token                30
# 499   3437         ABBC Coin    ABBC             abbc-coin                89
#
#                    date_added  \
# ...

# %%
import requests

# %%
page = requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/121.jpg","link":"https:\/\/randomfox.ca\/?i=121"}

# %%
fox = page.json()
image = fox['image']
print(image)
# Out:
# https://randomfox.ca/images/121.jpg

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.weatherapi.com/v1/current.json?key=c86177dae4104c4593f70959242002&q=London'  #actual url
parameters = {
  'start':'1',
  'limit':'2767',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '1f33914bca06477a93370314242002',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1708413619, 'localtime': '2024-02-20 7:20'}, 'current': {'last_updated_epoch': 1708413300, 'last_updated': '2024-02-20 07:15', 'temp_c': 6.0, 'temp_f': 42.8, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 240, 'wind_dir': 'WSW', 'pressure_mb': 1028.0, 'pressure_in': 30.36, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 93, 'cloud': 75, 'feelslike_c': 3.2, 'feelslike_f': 37.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 13.4, 'gust_kph': 21.6}}

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data)

# %%
norm
# Out:
#   location.name                 location.region location.country  \
# 0        London  City of London, Greater London   United Kingdom
#
#    location.lat  location.lon location.tz_id  location.localtime_epoch  \
# 0         51.52         -0.11  Europe/London                1708413619
#
#   location.localtime  current.last_updated_epoch current.last_updated  ...  \
# 0    2024-02-20 7:20                  1708413300     2024-02-20 07:15  ...
#
#    current.precip_in  current.humidity  current.cloud current.feelslike_c  \
# 0                0.0                93             75                 3.2
#
#   current.feelslike_f  current.vis_km  current.vis_miles  current.uv  \
# 0                37.8            10.0                6.0         1.0
#
#    current.gust_mph current.gust_kph
# 0              13.4             21.6
#
# [1 rows x 33 columns]

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.weatherapi.com/v1/current.json?key=c86177dae4104c4593f70959242002&q=London'  #actual url
parameters = {
  'start':'1',
  'limit':'2767',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd15f875f4c6f4865b8c70158242002',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1708418020, 'localtime': '2024-02-20 8:33'}, 'current': {'last_updated_epoch': 1708417800, 'last_updated': '2024-02-20 08:30', 'temp_c': 7.0, 'temp_f': 44.6, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 6.9, 'wind_kph': 11.2, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1028.0, 'pressure_in': 30.36, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 93, 'cloud': 75, 'feelslike_c': 4.3, 'feelslike_f': 39.7, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 2.0, 'gust_mph': 13.9, 'gust_kph': 22.4}}

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data)

# %%
norm
# Out:
#   location.name                 location.region location.country  \
# 0        London  City of London, Greater London   United Kingdom
#
#    location.lat  location.lon location.tz_id  location.localtime_epoch  \
# 0         51.52         -0.11  Europe/London                1708418020
#
#   location.localtime  current.last_updated_epoch current.last_updated  ...  \
# 0    2024-02-20 8:33                  1708417800     2024-02-20 08:30  ...
#
#    current.precip_in  current.humidity  current.cloud current.feelslike_c  \
# 0                0.0                93             75                 4.3
#
#   current.feelslike_f  current.vis_km  current.vis_miles  current.uv  \
# 0                39.7            10.0                6.0         2.0
#
#    current.gust_mph current.gust_kph
# 0              13.9             22.4
#
# [1 rows x 33 columns]
